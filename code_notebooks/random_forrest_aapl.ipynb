# %%
# %pip install pandas 
# %pip install numpy 
# %pip install scikit-learn
# %pip install matplotlib
# Out:
# Collecting pandas
#   Using cached pandas-2.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
# Collecting pytz>=2020.1
#   Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Requirement already satisfied: numpy>=1.22.4 in /home/josh/Dev/tyit_sem5/dmdw/dwdm_project/env/lib/python3.10/site-packages (from pandas) (2.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/josh/Dev/tyit_sem5/dmdw/dwdm_project/env/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Collecting tzdata>=2022.7
#   Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Requirement already satisfied: six>=1.5 in /home/josh/Dev/tyit_sem5/dmdw/dwdm_project/env/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Installing collected packages: pytz, tzdata, pandas
# Successfully installed pandas-2.2.2 pytz-2024.1 tzdata-2024.1
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in /home/josh/Dev/tyit_sem5/dmdw/dwdm_project/env/lib/python3.10/site-packages (2.1.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scikit-learn in /home/josh/Dev/tyit_sem5/dmdw/dwdm_project/env/lib/python3.10/site-packages (1.5.1)
# Requirement already satisfied: numpy>=1.19.5 in /home/josh/Dev/tyit_sem5/dmdw/dwdm_project/env/lib/python3.10/site-packages (from scikit-learn) (2.1.0)
# Requirement already satisfied: scipy>=1.6.0 in /home/josh/Dev/tyit_sem5/dmdw/dwdm_project/env/lib/python3.10/site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/josh/Dev/tyit_sem5/dmdw/dwdm_project/env/lib/python3.10/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/josh/Dev/tyit_sem5/dmdw/dwdm_project/env/lib/python3.10/site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in /home/josh/Dev/tyit_sem5/dmdw/dwdm_project/env/lib/python3.10/site-packages (3.9.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/josh/Dev/tyit_sem5/dmdw/dwdm_project/env/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/josh/Dev/tyit_sem5/dmdw/dwdm_project/env/lib/python3.10/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: pillow>=8 in /home/josh/Dev/tyit_sem5/dmdw/dwdm_project/env/lib/python3.10/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/josh/Dev/tyit_sem5/dmdw/dwdm_project/env/lib/python3.10/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/josh/Dev/tyit_sem5/dmdw/dwdm_project/env/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in /home/josh/Dev/tyit_sem5/dmdw/dwdm_project/env/lib/python3.10/site-packages (from matplotlib) (2.1.0)
# Requirement already satisfied: packaging>=20.0 in /home/josh/Dev/tyit_sem5/dmdw/dwdm_project/env/lib/python3.10/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/josh/Dev/tyit_sem5/dmdw/dwdm_project/env/lib/python3.10/site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: cycler>=0.10 in /home/josh/Dev/tyit_sem5/dmdw/dwdm_project/env/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: six>=1.5 in /home/josh/Dev/tyit_sem5/dmdw/dwdm_project/env/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np 
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt

# %%
#collect and clean data 
df = pd.read_csv('/home/josh/Dev/tyit_sem5/dmdw/dwdm_project/data/stocks/AAPL.csv')
df = df.dropna()

df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1980-12-12    0.513393    0.515625    0.513393    0.513393    0.406782
# 1     1980-12-15    0.488839    0.488839    0.486607    0.486607    0.385558
# 2     1980-12-16    0.453125    0.453125    0.450893    0.450893    0.357260
# 3     1980-12-17    0.462054    0.464286    0.462054    0.462054    0.366103
# 4     1980-12-18    0.475446    0.477679    0.475446    0.475446    0.376715
# ...          ...         ...         ...         ...         ...         ...
# 9904  2020-03-26  246.520004  258.679993  246.360001  258.440002  258.440002
# 9905  2020-03-27  252.750000  255.869995  247.050003  247.740005  247.740005
# 9906  2020-03-30  250.740005  255.520004  249.399994  254.809998  254.809998
# 9907  2020-03-31  255.600006  262.489990  252.000000  254.289993  254.289993
# 9908  2020-04-01  246.500000  248.720001  239.130005  240.910004  240.910004
#
#          Volume
# 0     117258400
# 1      43971200
# 2      26432000
# 3      21610400
# 4      18362400
# ...         ...
# 9904   63021800
# 9905   51054200
# 9906   41994100
# 9907   49250500
# 9908   43956200
#
# [9909 rows x 7 columns]

# %%
#show the data visually 
df.plot(x="Date", y= "Close")
plt.xticks(rotation = 45)
# Out:
# (array([-2000.,     0.,  2000.,  4000.,  6000.,  8000., 10000., 12000.]),
#  [Text(-2000.0, 0, '2012-04-20'),
#   Text(0.0, 0, '1980-12-12'),
#   Text(2000.0, 0, '1988-11-10'),
#   Text(4000.0, 0, '1996-10-09'),
#   Text(6000.0, 0, '2004-09-22'),
#   Text(8000.0, 0, '2012-08-29'),
#   Text(10000.0, 0, ''),
#   Text(12000.0, 0, '')])

# %%
#create the model 
model = RandomForestRegressor()

# %%
#train the model 

x = df[['Open','High','Low','Volume']]
x = x[:int(len(df)-1)]
y = df['Close']
y = y[:int(len(df)-1)]
model.fit(x,y) # to train the model
# Out:
# RandomForestRegressor()

# %%
#test the model 
predictions = model.predict(x)
print('the model score is: ', model.score(x,y))
# Out:
# the model score is:  0.9999845157946995

# %%
#make the predictions: 
new_data = df[['Open','High','Low','Volume']].tail(1)
prediction = model.predict(new_data)
print("the model predicts the last row or day to be:", prediction)
print("actual value: " ,df[['Close']].tail(1).values[0][0])
# Out:
# the model predicts the last row or day to be: [246.54889832]
# actual value:  240.91000366210935
